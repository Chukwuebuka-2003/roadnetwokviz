# %%
import osmnx as ox

# %%
admin = ox.geocode_to_gdf('Ikeja')
admin_poly = admin.geometry.values[0]
admin_poly
# Out:
# <POLYGON ((3.31 6.551, 3.318 6.551, 3.318 6.551, 3.322 6.554, 3.322 6.555, 3...>

# %%
G = ox.graph_from_polygon(admin_poly)

# %%
G.number_of_nodes(), G.number_of_edges()
# Out:
# (5832, 12560)

# %%
nodes, edges = ox.graph_to_gdfs(G)

# %%
import matplotlib.pyplot as plt

plt.style.use('dark_background')

# %%
f, ax = plt.subplots(1, 1, figsize= (10,10))
edges.plot(ax=ax, edgecolor= 'orange', linewidth=0.3)
ax.axis('off')
# Out:
# (3.3149457900000003, 3.38583221, 6.551003345, 6.662009955)
